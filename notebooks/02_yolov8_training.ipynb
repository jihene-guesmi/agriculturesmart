# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/jiheneguesmi/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#yolo model
model = YOLO("yolov8n.pt")

# %%
#train model
results = model.train(
    data="../detection/data.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    name="pomegranate_detector"
)
# Out:
# Ultralytics 8.4.50 🚀 Python-3.14.0 torch-2.12.0 CPU (Apple M1)
# ...
